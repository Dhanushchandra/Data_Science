# %%
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./data/auto-mpg.csv')

# %%
sns.histplot(df["displacement"], color="red")
# Out:
# <Axes: xlabel='displacement', ylabel='Count'>

# %%
sns.histplot(df["acceleration"], color="orange")
# Out:
# <Axes: xlabel='acceleration', ylabel='Count'>

# %%
sns.scatterplot(x="acceleration", y='displacement', data=df)
# Out:
# <Axes: xlabel='acceleration', ylabel='displacement'>

# %%
sns.countplot(x="acceleration", data=df)
# Out:
# <Axes: xlabel='acceleration', ylabel='count'>

# %%
sns.pointplot(x="weight", y="horsepower", data=df)
# Out:
# <Axes: xlabel='weight', ylabel='horsepower'>
